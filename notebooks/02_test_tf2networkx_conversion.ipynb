# %% [markdown]
# # Testing Conversion
# This notebook is used for some simple poking around and testing the components
# needed for converting a networkx graph with standard ONNX operator types to a
# networkx graph with tensorflow operator types.
#
# The basic conversion flow is:
# networkx graph (onnx ops) -> standard onnx -> tf -> networkx graph (tf ops)

# %%
import os
import pathlib
import json

import numpy as np
import tensorflow as tf

import onnx
from onnx.shape_inference import infer_shapes

from youngernns.data.network import Network
from youngernns.nn_translation import networkx_to_onnx

# %% [markdown]
# ## Global Variables

# %%
DATA_PATH = os.path.join("..","data","filter_series_with_attributes_paper")
OUTPUT_DIR = os.path.join("..", "output")

# %% [markdown]
# ## Loading Data

# %%
def get_graph_paths():
    # find all paths for network folders DATA_PATH/gaphd_id/network/
    graph_folders = []
    for root, dirs, files in os.walk(DATA_PATH):
        if 'network' in dirs:
            graph_folders.append(os.path.join(root, 'network'))
    return graph_folders

# %%
graph_paths = get_graph_paths()
print(f"Found {len(graph_paths)} graphs")
print(f"Example of first graph path: {graph_paths[0]}")
# Out:
# Found 7629 graphs
# Example of first graph path: ../data/filter_series_with_attributes_paper/0ad2b9b313487b294428174cf56d7d22/network

# %% [markdown]
# Let's test the conversion on the first graph path

# %%
NN = Network()
NN.load(pathlib.Path(graph_paths[0]))

onnx_model = networkx_to_onnx(NN.graph, input_shape=(1, 128, 128, 3), output_shape=(1,2))
shaped_onnx_model = infer_shapes(onnx_model)

# %%
shaped_onnx_model.graph.node
# Out:
# [input: "data"
# output: "node_0"
# name: "node_0"
# op_type: "Transpose"
# attribute {
#   name: "perm"
#   ints: 0
#   ints: 3
#   ints: 1
#   ints: 2
#   type: INTS
# }
# , input: "node_0"
# input: "Conv_weights_1"
# output: "node_1"
# name: "node_1"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 1
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 3
#   ints: 3
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# , input: "node_1"
# output: "node_2"
# name: "node_2"
# op_type: "Relu"
# , input: "node_2"
# output: "node_3"
# name: "node_3"
# op_type: "MaxPool"
# attribute {
#   name: "ceil_mode"
#   i: 0
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 2
#   ints: 2
#   type: INTS
# }
# attribute {
#   name: "storage_order"
#   i: 0
#   type: INT
# }
# attribute {
#   name: "strides"
#   ints: 2
#   ints: 2
#   type: INTS
# }
# , input: "node_3"
# input: "Conv_weights_4"
# output: "node_4"
# name: "node_4"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 1
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 3
#   ints: 3
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# , input: "node_4"
# output: "node_5"
# name: "node_5"
# op_type: "Relu"
# , input: "node_5"
# output: "node_6"
# name: "node_6"
# op_type: "MaxPool"
# attribute {
#   name: "ceil_mode"
#   i: 0
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 2
#   ints: 2
#   type: INTS
# }
# attribute {
#   name: "storage_order"
#   i: 0
#   type: INT
# }
# attribute {
#   name: "strides"
#   ints: 2
#   ints: 2
#   type: INTS
# }
# , input: "node_6"
# input: "Conv_weights_7"
# output: "node_7"
# name: "node_7"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 1
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 3
#   ints: 3
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# , input: "node_7"
# output: "node_8"
# name: "node_8"
# op_type: "Relu"
# , input: "node_8"
# output: "node_9"
# name: "node_9"
# op_type: "MaxPool"
# attribute {
#   name: "ceil_mode"
#   i: 0
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 2
#   ints: 2
#   type: INTS
# }
# attribute {
#   name: "storage_order"
#   i: 0
#   type: INT
# }
# attribute {
#   name: "strides"
#   ints: 2
#   ints: 2
#   type: INTS
# }
# , input: "node_9"
# output: "node_10"
# name: "node_10"
# op_type: "Transpose"
# attribute {
#   name: "perm"
#   ints: 0
#   ints: 2
#   ints: 3
#   ints: 1
#   type: INTS
# }
# , input: "node_10"
# input: "Reshape_shape_11"
# output: "node_11"
# name: "node_11"
# op_type: "Reshape"
# attribute {
#   name: "allowzero"
#   i: 0
#   type: INT
# }
# , input: "node_11"
# input: "Matmul_Y_12"
# output: "node_12"
# name: "node_12"
# op_type: "MatMul"
# , input: "node_12"
# input: "Add_Y_13"
# output: "node_13"
# name: "node_13"
# op_type: "Add"
# , input: "node_13"
# output: "node_14"
# name: "node_14"
# op_type: "Relu"
# , input: "node_14"
# input: "Matmul_Y_15"
# output: "node_15"
# name: "node_15"
# op_type: "MatMul"
# , input: "node_15"
# input: "Add_Y_16"
# output: "node_16"
# name: "node_16"
# op_type: "Add"
# , input: "node_16"
# output: "node_17"
# name: "node_17"
# op_type: "Softmax"
# attribute {
#   name: "axis"
#   i: -1
#   type: INT
# }
# ]

# %%
# Load tensorflow tensor image
image_path = os.path.join("..", "output", "tf_images", "corgi_128_tensor.npy")

# Load tensor
def load_npy_tensor(file_path):
    # Load the .npy file
    np_tensor = np.load(file_path)
    
    # Convert the numpy array to a TensorFlow tensor
    tf_tensor = tf.convert_to_tensor(np_tensor, dtype=tf.float32)
    return tf_tensor

img = load_npy_tensor(image_path)

# %%
img.shape
# Out:
# TensorShape([1, 128, 128, 3])

# %%
from onnx.reference import ReferenceEvaluator
oinf = ReferenceEvaluator(shaped_onnx_model, verbose=3)
oinf.run(None, {"data": img})
# Out:
#  +C Conv_weights_1: float32:(3, 3, 3, 3) in [0.018789799883961678, 0.9883738160133362]
#  +C Conv_weights_4: float32:(3, 3, 3, 3) in [0.004695476032793522, 0.9988470077514648]
#  +C Conv_weights_7: float32:(3, 3, 3, 3) in [0.011714084073901176, 0.990338921546936]
#  +C Reshape_shape_11: int64:(2,) in [-1, 1]
#  +C Matmul_Y_12: float32:(588, 2) in [0.0005459649255499244, 0.9998085498809814]
#  +C Add_Y_13: float32:(1, 2) in [0.049499742686748505, 0.6854671239852905]
#  +C Matmul_Y_15: float32:(2, 2) in [0.10185461491346359, 0.3165411353111267]
#  +C Add_Y_16: float32:(1, 2) in [0.2550637722015381, 0.7505366802215576]
#  +I data: tf.Tensor(
# [[[[0.34509805 0.30980393 0.27450982]
#    [0.34901962 0.31764707 0.28627452]
#    [0.34509805 0.31764707 0.28627452]
#    ...
#    [0.16078432 0.15686275 0.15686275]
#    [0.16470589 0.16862746 0.16078432]
#    [0.1764706  0.1764706  0.16862746]]
#
#   [[0.3529412  0.31764707 0.28627452]
#    [0.34901962 0.3254902  0.29411766]
#    [0.33333334 0.3137255  0.28235295]
#    ...
#    [0.16078432 0.16078432 0.16078432]
#    [0.16470589 0.16470589 0.16078432]
#    [0.17254902 0.1764706  0.16470589]]
#
#   [[0.36862746 0.3372549  0.3019608 ]
#    [0.34901962 0.32156864 0.2901961 ]
#    [0.3254902  0.3019608  0.27058825]
#    ...
#    [0.16078432 0.16078432 0.16078432]
#    [0.16470589 0.16470589 0.16470589]
#    [0.17254902 0.17254902 0.16862746]]
#
#   ...
#
#   [[0.29803923 0.43137255 0.25490198]
#    [0.35686275 0.48235294 0.28235295]
#    [0.35686275 0.4627451  0.2       ]
#    ...
#    [0.56078434 0.54509807 0.09803922]
#    [0.42745098 0.4745098  0.16862746]
#    [0.4862745  0.5019608  0.07450981]]
#
#   [[0.29411766 0.42745098 0.23921569]
#    [0.33333334 0.46666667 0.26666668]
#    [0.3372549  0.4509804  0.19607843]
#    ...
#    [0.56078434 0.5372549  0.07058824]
#    [0.5372549  0.53333336 0.16470589]
#    [0.45882353 0.48235294 0.03137255]]
#
#   [[0.2627451  0.40784314 0.18039216]
#    [0.31764707 0.44705883 0.23529412]
#    [0.33333334 0.44705883 0.19607843]
#    ...
#    [0.5058824  0.5058824  0.03529412]
#    [0.47058824 0.47058824 0.08235294]
#    [0.42745098 0.4745098  0.01176471]]]], shape=(1, 128, 128, 3), dtype=float32)
# Transpose(data) -> node_0
#  + node_0: float32:(1, 3, 128, 128) in [0.0, 1.0]
# Conv(node_0, Conv_weights_1) -> node_1
#  + node_1: float32:(1, 3, 126, 126) in [0.6754682064056396, 14.20429801940918]
# Relu(node_1) -> node_2
#  + node_2: float32:(1, 3, 126, 126) in [0.6754682064056396, 14.20429801940918]
# MaxPool(node_2) -> node_3
#  + node_3: float32:(1, 3, 63, 63) in [1.0592775344848633, 14.20429801940918]
# Conv(node_3, Conv_weights_4) -> node_4
#  + node_4: float32:(1, 3, 61, 61) in [22.146371841430664, 185.4886932373047]
# Relu(node_4) -> node_5
#  + node_5: float32:(1, 3, 61, 61) in [22.146371841430664, 185.4886932373047]
# MaxPool(node_5) -> node_6
#  + node_6: float32:(1, 3, 30, 30) in [26.838394165039062, 185.4886932373047]
# Conv(node_6, Conv_weights_7) -> node_7
#  + node_7: float32:(1, 3, 28, 28) in [388.95947265625, 2201.35302734375]
# Relu(node_7) -> node_8
#  + node_8: float32:(1, 3, 28, 28) in [388.95947265625, 2201.35302734375]
# MaxPool(node_8) -> node_9
#  + node_9: float32:(1, 3, 14, 14) in [433.4344482421875, 2201.35302734375]
# Transpose(node_9) -> node_10
#  + node_10: float32:(1, 14, 14, 3) in [433.4344482421875, 2201.35302734375]
# Reshape(node_10, Reshape_shape_11) -> node_11
#  + node_11: float32:(1, 588) in [433.4344482421875, 2201.35302734375]
# MatMul(node_11, Matmul_Y_12) -> node_12
#  + node_12: float32:(1, 2) in [330837.46875, 331405.0625]
# Add(node_12, Add_Y_13) -> node_13
#  + node_13: float32:(1, 2) in [330837.53125, 331405.75]
# Relu(node_13) -> node_14
#  + node_14: float32:(1, 2) in [330837.53125, 331405.75]
# MatMul(node_14, Matmul_Y_15) -> node_15
#  + node_15: float32:(1, 2) in [138478.890625, 143303.71875]
# Add(node_15, Add_Y_16) -> node_16
#  + node_16: float32:(1, 2) in [138479.140625, 143304.46875]
# Softmax(node_16) -> node_17
#  + node_17: float32:(1, 2) in [0.0, 1.0]
# [array([[0., 1.]], dtype=float32)]

# %%
# Save the onnx model
onnx_path = os.path.join(OUTPUT_DIR, "onnx_model.onnx")
with open(onnx_path, "wb") as f:
    f.write(onnx_model.SerializeToString())

# %%
onnx.checker.check_model(onnx_path)

# %% [markdown]
# Now let's try and convert the onnx model to tensorflow format.

# %%
! onnx2tf -i ../output/onnx_model.onnx -o ../output/tf_onnx_model -b 1 -kat data
# Out:
# Model optimizing started ============================================================
# Traceback (most recent call last):
#   File "/home/wdm/YoungerNNs/.venv/lib/python3.12/site-packages/onnx2tf/onnx2tf.py", line 645, in convert
#     result = subprocess.check_output(
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/subprocess.py", line 466, in check_output
#     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/subprocess.py", line 571, in run
#     raise CalledProcessError(retcode, process.args,
# subprocess.CalledProcessError: Command '['onnxsim', '../output/onnx_model.onnx', '../output/onnx_model.onnx']' returned non-zero exit status 1.
#
# WARNING: Failed to optimize the onnx file.
#
# Automatic generation of each OP name started ========================================
# Automatic generation of each OP name complete!
#
# Model loaded ========================================================================
#
# Model conversion started ============================================================
# INFO: input_op_name: data shape: [1, 128, 128, 3] dtype: float32
# WARNING: The optimization process for shape estimation is skipped because it contains OPs that cannot be inferred by the standard onnxruntime.
# WARNING: name 'ort' is not defined
#
# INFO: 2 / 19
# INFO: onnx_op_type: Transpose onnx_op_name: node_0
# INFO:  input_name.1: data shape: [1, 128, 128, 3] dtype: float32
# INFO:  output_name.1: node_0 shape: [1, 3, 128, 128] dtype: float32
# INFO: tf_op_type: transpose_v2
# INFO:  input.1.a: name: data shape: (1, 128, 128, 3) dtype: <dtype: 'float32'>
# INFO:  input.2.perm: val: [0, 3, 1, 2]
# INFO:  output.1.output: name: tf.compat.v1.transpose/transpose:0 shape: (1, 3, 128, 128) dtype: <dtype: 'float32'>
#
# INFO: 3 / 19
# INFO: onnx_op_type: Conv onnx_op_name: node_1
# INFO:  input_name.1: node_0 shape: [1, 3, 128, 128] dtype: float32
# INFO:  input_name.2: Conv_weights_1 shape: [3, 3, 3, 3] dtype: float32
# INFO:  output_name.1: node_1 shape: [1, 3, 126, 126] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.compat.v1.transpose_1/transpose:0 shape: (1, 128, 128, 3) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 3, 3) dtype: <dtype: 'float32'>
# INFO:  input.3.bias:
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: VALID
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.nn.convolution/convolution:0 shape: (1, 126, 126, 3) dtype: <dtype: 'float32'>
#
# INFO: 4 / 19
# INFO: onnx_op_type: Relu onnx_op_name: node_2
# INFO:  input_name.1: node_1 shape: [1, 3, 126, 126] dtype: float32
# INFO:  output_name.1: node_2 shape: [1, 3, 126, 126] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.nn.convolution/convolution:0 shape: (1, 126, 126, 3) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu/Relu:0 shape: (1, 126, 126, 3) dtype: <dtype: 'float32'>
#
# INFO: 5 / 19
# INFO: onnx_op_type: MaxPool onnx_op_name: node_3
# INFO:  input_name.1: node_2 shape: [1, 3, 126, 126] dtype: float32
# INFO:  output_name.1: node_3 shape: [1, 3, 63, 63] dtype: float32
# INFO: tf_op_type: max_pool_v2
# INFO:  input.1.input: name: tf.nn.relu/Relu:0 shape: (1, 126, 126, 3) dtype: <dtype: 'float32'>
# INFO:  input.2.filters:
# INFO:  input.3.kernel_shape: val: [2, 2]
# INFO:  input.4.strides: val: [2, 2]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: [0, 0, 0, 0]
# INFO:  input.7.ceil_mode: val: False
# INFO:  output.1.output0: name: tf.nn.max_pool2d/MaxPool2d:0 shape: (1, 63, 63, 3) dtype: <dtype: 'float32'>
# INFO:  output.2.output1:
#
# INFO: 6 / 19
# INFO: onnx_op_type: Conv onnx_op_name: node_4
# INFO:  input_name.1: node_3 shape: [1, 3, 63, 63] dtype: float32
# INFO:  input_name.2: Conv_weights_4 shape: [3, 3, 3, 3] dtype: float32
# INFO:  output_name.1: node_4 shape: [1, 3, 61, 61] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.nn.max_pool2d/MaxPool2d:0 shape: (1, 63, 63, 3) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 3, 3) dtype: <dtype: 'float32'>
# INFO:  input.3.bias:
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: VALID
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.nn.convolution_1/convolution:0 shape: (1, 61, 61, 3) dtype: <dtype: 'float32'>
#
# INFO: 7 / 19
# INFO: onnx_op_type: Relu onnx_op_name: node_5
# INFO:  input_name.1: node_4 shape: [1, 3, 61, 61] dtype: float32
# INFO:  output_name.1: node_5 shape: [1, 3, 61, 61] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.nn.convolution_1/convolution:0 shape: (1, 61, 61, 3) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu_1/Relu:0 shape: (1, 61, 61, 3) dtype: <dtype: 'float32'>
#
# INFO: 8 / 19
# INFO: onnx_op_type: MaxPool onnx_op_name: node_6
# INFO:  input_name.1: node_5 shape: [1, 3, 61, 61] dtype: float32
# INFO:  output_name.1: node_6 shape: [1, 3, 30, 30] dtype: float32
# INFO: tf_op_type: max_pool_v2
# INFO:  input.1.input: name: tf.nn.relu_1/Relu:0 shape: (1, 61, 61, 3) dtype: <dtype: 'float32'>
# INFO:  input.2.filters:
# INFO:  input.3.kernel_shape: val: [2, 2]
# INFO:  input.4.strides: val: [2, 2]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: [0, 0, 0, 0]
# INFO:  input.7.ceil_mode: val: False
# INFO:  output.1.output0: name: tf.nn.max_pool2d_1/MaxPool2d:0 shape: (1, 30, 30, 3) dtype: <dtype: 'float32'>
# INFO:  output.2.output1:
#
# INFO: 9 / 19
# INFO: onnx_op_type: Conv onnx_op_name: node_7
# INFO:  input_name.1: node_6 shape: [1, 3, 30, 30] dtype: float32
# INFO:  input_name.2: Conv_weights_7 shape: [3, 3, 3, 3] dtype: float32
# INFO:  output_name.1: node_7 shape: [1, 3, 28, 28] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.nn.max_pool2d_1/MaxPool2d:0 shape: (1, 30, 30, 3) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 3, 3) dtype: <dtype: 'float32'>
# INFO:  input.3.bias:
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: VALID
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.nn.convolution_2/convolution:0 shape: (1, 28, 28, 3) dtype: <dtype: 'float32'>
#
# INFO: 10 / 19
# INFO: onnx_op_type: Relu onnx_op_name: node_8
# INFO:  input_name.1: node_7 shape: [1, 3, 28, 28] dtype: float32
# INFO:  output_name.1: node_8 shape: [1, 3, 28, 28] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.nn.convolution_2/convolution:0 shape: (1, 28, 28, 3) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu_2/Relu:0 shape: (1, 28, 28, 3) dtype: <dtype: 'float32'>
#
# INFO: 11 / 19
# INFO: onnx_op_type: MaxPool onnx_op_name: node_9
# INFO:  input_name.1: node_8 shape: [1, 3, 28, 28] dtype: float32
# INFO:  output_name.1: node_9 shape: [1, 3, 14, 14] dtype: float32
# INFO: tf_op_type: max_pool_v2
# INFO:  input.1.input: name: tf.nn.relu_2/Relu:0 shape: (1, 28, 28, 3) dtype: <dtype: 'float32'>
# INFO:  input.2.filters:
# INFO:  input.3.kernel_shape: val: [2, 2]
# INFO:  input.4.strides: val: [2, 2]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: [0, 0, 0, 0]
# INFO:  input.7.ceil_mode: val: False
# INFO:  output.1.output0: name: tf.nn.max_pool2d_2/MaxPool2d:0 shape: (1, 14, 14, 3) dtype: <dtype: 'float32'>
# INFO:  output.2.output1:
#
# INFO: 12 / 19
# INFO: onnx_op_type: Transpose onnx_op_name: node_10
# INFO:  input_name.1: node_9 shape: [1, 3, 14, 14] dtype: float32
# INFO:  output_name.1: node_10 shape: [1, 14, 14, 3] dtype: float32
# INFO: tf_op_type: transpose_v2
# INFO:  input.1.a: name: tf.nn.max_pool2d_2/MaxPool2d:0 shape: (1, 14, 14, 3) dtype: <dtype: 'float32'>
# INFO:  input.2.perm: val: [0, 1, 2, 3]
# INFO:  output.1.output: name: tf.nn.max_pool2d_2/MaxPool2d:0 shape: (1, 14, 14, 3) dtype: <dtype: 'float32'>
#
# INFO: 13 / 19
# INFO: onnx_op_type: Reshape onnx_op_name: node_11
# INFO:  input_name.1: node_10 shape: [1, 14, 14, 3] dtype: float32
# INFO:  input_name.2: Reshape_shape_11 shape: [2] dtype: int64
# INFO:  output_name.1: node_11 shape: [1, 588] dtype: float32
# INFO: tf_op_type:
# INFO:  input.1.tensor: name: tf.nn.max_pool2d_2/MaxPool2d:0 shape: (1, 14, 14, 3) dtype: <dtype: 'float32'>
# INFO:  input.2.shape: val: [1, -1]
# INFO:  output.1.output: name: tf.reshape/Reshape:0 shape: (1, 588) dtype: <dtype: 'float32'>
#
# INFO: 14 / 19
# INFO: onnx_op_type: MatMul onnx_op_name: node_12
# INFO:  input_name.1: node_11 shape: [1, 588] dtype: float32
# INFO:  input_name.2: Matmul_Y_12 shape: [588, 2] dtype: float32
# INFO:  output_name.1: node_12 shape: [1, 2] dtype: float32
# INFO: tf_op_type: matmul
# INFO:  input.1.a: name: tf.reshape/Reshape:0 shape: (1, 588) dtype: <dtype: 'float32'>
# INFO:  input.2.b: shape: (588, 2) dtype: float32
# INFO:  input.3.output_type: name: float32 shape: ()
# INFO:  output.1.output: name: tf.linalg.matmul/MatMul:0 shape: (1, 2) dtype: <dtype: 'float32'>
#
# INFO: 15 / 19
# INFO: onnx_op_type: Add onnx_op_name: node_13
# INFO:  input_name.1: node_12 shape: [1, 2] dtype: float32
# INFO:  input_name.2: Add_Y_13 shape: [1, 2] dtype: float32
# INFO:  output_name.1: node_13 shape: [1, 2] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.linalg.matmul/MatMul:0 shape: (1, 2) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: (1, 2) dtype: float32
# INFO:  output.1.output: name: tf.math.add/Add:0 shape: (1, 2) dtype: <dtype: 'float32'>
#
# INFO: 16 / 19
# INFO: onnx_op_type: Relu onnx_op_name: node_14
# INFO:  input_name.1: node_13 shape: [1, 2] dtype: float32
# INFO:  output_name.1: node_14 shape: [1, 2] dtype: float32
# INFO: tf_op_type: relu
# INFO:  input.1.features: name: tf.math.add/Add:0 shape: (1, 2) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.nn.relu_3/Relu:0 shape: (1, 2) dtype: <dtype: 'float32'>
#
# INFO: 17 / 19
# INFO: onnx_op_type: MatMul onnx_op_name: node_15
# INFO:  input_name.1: node_14 shape: [1, 2] dtype: float32
# INFO:  input_name.2: Matmul_Y_15 shape: [2, 2] dtype: float32
# INFO:  output_name.1: node_15 shape: [1, 2] dtype: float32
# INFO: tf_op_type: matmul
# INFO:  input.1.a: name: tf.nn.relu_3/Relu:0 shape: (1, 2) dtype: <dtype: 'float32'>
# INFO:  input.2.b: shape: (2, 2) dtype: float32
# INFO:  input.3.output_type: name: float32 shape: ()
# INFO:  output.1.output: name: tf.linalg.matmul_1/MatMul:0 shape: (1, 2) dtype: <dtype: 'float32'>
#
# INFO: 18 / 19
# INFO: onnx_op_type: Add onnx_op_name: node_16
# INFO:  input_name.1: node_15 shape: [1, 2] dtype: float32
# INFO:  input_name.2: Add_Y_16 shape: [1, 2] dtype: float32
# INFO:  output_name.1: node_16 shape: [1, 2] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.linalg.matmul_1/MatMul:0 shape: (1, 2) dtype: <dtype: 'float32'>
# INFO:  input.2.y: shape: (1, 2) dtype: float32
# INFO:  output.1.output: name: tf.math.add_1/Add:0 shape: (1, 2) dtype: <dtype: 'float32'>
#
# INFO: 19 / 19
# INFO: onnx_op_type: Softmax onnx_op_name: node_17
# INFO:  input_name.1: node_16 shape: [1, 2] dtype: float32
# INFO:  output_name.1: node_17 shape: [1, 2] dtype: float32
# INFO: tf_op_type: softmax_v2
# INFO:  input.1.logits: name: tf.math.add_1/Add:0 shape: (1, 2) dtype: <dtype: 'float32'>
# INFO:  input.2.axis: val: 1
# INFO:  output.1.output: name: tf.nn.softmax/node_17:0 shape: (1, 2) dtype: <dtype: 'float32'>
#
# saved_model output started ==========================================================
# Saved artifact at '../output/tf_onnx_model'. The following endpoints are available:
#
# * Endpoint 'serving_default'
#   inputs_0 (POSITIONAL_ONLY): TensorSpec(shape=(1, 128, 128, 3), dtype=tf.float32, name='data')
# Output Type:
#   TensorSpec(shape=(1, 2), dtype=tf.float32, name=None)
# Captures:
#   135650187402832: TensorSpec(shape=(3, 3, 3, 3), dtype=tf.float32, name=None)
#   135650187403600: TensorSpec(shape=(3, 3, 3, 3), dtype=tf.float32, name=None)
#   135650187405328: TensorSpec(shape=(3, 3, 3, 3), dtype=tf.float32, name=None)
#   135650187400720: TensorSpec(shape=(588, 2), dtype=tf.float32, name=None)
#   135650187404944: TensorSpec(shape=(1, 2), dtype=tf.float32, name=None)
#   135650187402640: TensorSpec(shape=(2, 2), dtype=tf.float32, name=None)
#   135650187400336: TensorSpec(shape=(1, 2), dtype=tf.float32, name=None)
# saved_model output complete!
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1731332600.440982  119189 devices.cc:67] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1731332600.535985  119189 tf_tfl_flatbuffer_helpers.cc:392] Ignored output_format.
# W0000 00:00:1731332600.536012  119189 tf_tfl_flatbuffer_helpers.cc:395] Ignored drop_control_dependency.
# Float32 tflite output complete!
# I0000 00:00:1731332600.592831  119189 devices.cc:67] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# W0000 00:00:1731332600.671596  119189 tf_tfl_flatbuffer_helpers.cc:392] Ignored output_format.
# W0000 00:00:1731332600.671611  119189 tf_tfl_flatbuffer_helpers.cc:395] Ignored drop_control_dependency.
# Float16 tflite output complete!

# %% [markdown]
# Now, we load the tensorflow model and look at the operator names.

# %%
# Load tensorflow model from output/tf_onnx_model
tf_model = tf.saved_model.load("../output/tf_onnx_model")

# %%
type(tf_model)
# Out:
# tensorflow.python.saved_model.load.Loader._recreate_base_user_object.<locals>._UserObject

# %% [markdown]
# Now let's look at the operators in the tensorflow graph

# %%
concrete_func = tf_model.signatures['serving_default']
tf_graph =concrete_func.graph.as_graph_def()

# %%
tf_graph
# Out:
# node {
#   name: "data"
#   op: "Placeholder"
#   attr {
#     key: "_user_specified_name"
#     value {
#       s: "data"
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 1
#         }
#         dim {
#           size: 128
#         }
#         dim {
#           size: 128
#         }
#         dim {
#           size: 3
#         }
#       }
#     }
#   }
# }
# node {
#   name: "unknown"
#   op: "Placeholder"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 3
#         }
#         dim {
#           size: 3
#         }
#         dim {
#           size: 3
#         }
#         dim {
#           size: 3
#         }
#       }
#     }
#   }
# }
# node {
#   name: "unknown_0"
#   op: "Placeholder"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 3
#         }
#         dim {
#           size: 3
#         }
#         dim {
#           size: 3
#         }
#         dim {
#           size: 3
#         }
#       }
#     }
#   }
# }
# node {
#   name: "unknown_1"
#   op: "Placeholder"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 3
#         }
#         dim {
#           size: 3
#         }
#         dim {
#           size: 3
#         }
#         dim {
#           size: 3
#         }
#       }
#     }
#   }
# }
# node {
#   name: "unknown_2"
#   op: "Placeholder"
#   attr {
#     key: "_user_specified_name"
#     value {
#       s: "313"
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 588
#         }
#         dim {
#           size: 2
#         }
#       }
#     }
#   }
# }
# node {
#   name: "unknown_3"
#   op: "Placeholder"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 1
#         }
#         dim {
#           size: 2
#         }
#       }
#     }
#   }
# }
# node {
#   name: "unknown_4"
#   op: "Placeholder"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 2
#         }
#         dim {
#           size: 2
#         }
#       }
#     }
#   }
# }
# node {
#   name: "unknown_5"
#   op: "Placeholder"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 1
#         }
#         dim {
#           size: 2
#         }
#       }
#     }
#   }
# }
# node {
#   name: "PartitionedCall"
#   op: "PartitionedCall"
#   input: "data"
#   input: "unknown"
#   input: "unknown_0"
#   input: "unknown_1"
#   input: "unknown_2"
#   input: "unknown_3"
#   input: "unknown_4"
#   input: "unknown_5"
#   attr {
#     key: "Tin"
#     value {
#       list {
#         type: DT_FLOAT
#         type: DT_FLOAT
#         type: DT_FLOAT
#         type: DT_FLOAT
#         type: DT_FLOAT
#         type: DT_FLOAT
#         type: DT_FLOAT
#         type: DT_FLOAT
#       }
#     }
#   }
#   attr {
#     key: "Tout"
#     value {
#       list {
#         type: DT_FLOAT
#       }
#     }
#   }
#   attr {
#     key: "_collective_manager_ids"
#     value {
#       list {
#       }
#     }
#   }
#   attr {
#     key: "_read_only_resource_inputs"
#     value {
#       list {
#       }
#     }
#   }
#   attr {
#     key: "config"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "config_proto"
#     value {
#       s: "\n\007\n\003CPU\020\001\n\007\n\003GPU\020\0002\002J\0008\001\202\001\000"
#     }
#   }
#   attr {
#     key: "executor_type"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "f"
#     value {
#       func {
#         name: "__inference_<lambda>_34"
#       }
#     }
#   }
# }
# node {
#   name: "Identity"
#   op: "Identity"
#   input: "PartitionedCall"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# library {
#   function {
#     signature {
#       name: "__inference_<lambda>_34"
#       input_arg {
#         name: "data"
#         type: DT_FLOAT
#       }
#       input_arg {
#         name: "model_1_tf_nn_convolution_convolution_filter"
#         type: DT_FLOAT
#       }
#       input_arg {
#         name: "model_1_tf_nn_convolution_1_convolution_filter"
#         type: DT_FLOAT
#       }
#       input_arg {
#         name: "model_1_tf_nn_convolution_2_convolution_filter"
#         type: DT_FLOAT
#       }
#       input_arg {
#         name: "model_1_tf_linalg_matmul_matmul_b"
#         type: DT_FLOAT
#       }
#       input_arg {
#         name: "model_1_tf_math_add_add_y"
#         type: DT_FLOAT
#       }
#       input_arg {
#         name: "model_1_tf_linalg_matmul_1_matmul_b"
#         type: DT_FLOAT
#       }
#       input_arg {
#         name: "model_1_tf_math_add_1_add_y"
#         type: DT_FLOAT
#       }
#       output_arg {
#         name: "identity"
#         type: DT_FLOAT
#       }
#     }
#     node_def {
#       name: "model_1/tf.compat.v1.transpose/transpose/perm"
#       op: "Const"
#       attr {
#         key: "dtype"
#         value {
#           type: DT_INT32
#         }
#       }
#       attr {
#         key: "value"
#         value {
#           tensor {
#             dtype: DT_INT32
#             tensor_shape {
#               dim {
#                 size: 4
#               }
#             }
#             tensor_content: "\000\000\000\000\003\000\000\000\001\000\000\000\002\000\000\000"
#           }
#         }
#       }
#     }
#     node_def {
#       name: "model_1/tf.compat.v1.transpose/transpose"
#       op: "Transpose"
#       input: "data"
#       input: "model_1/tf.compat.v1.transpose/transpose/perm:output:0"
#       attr {
#         key: "T"
#         value {
#           type: DT_FLOAT
#         }
#       }
#       attr {
#         key: "Tperm"
#         value {
#           type: DT_INT32
#         }
#       }
#     }
#     node_def {
#       name: "model_1/tf.compat.v1.transpose_1/transpose/perm"
#       op: "Const"
#       attr {
#         key: "dtype"
#         value {
#           type: DT_INT32
#         }
#       }
#       attr {
#         key: "value"
#         value {
#           tensor {
#             dtype: DT_INT32
#             tensor_shape {
#               dim {
#                 size: 4
#               }
#             }
#             tensor_content: "\000\000\000\000\002\000\000\000\003\000\000\000\001\000\000\000"
#           }
#         }
#       }
#     }
#     node_def {
#       name: "model_1/tf.compat.v1.transpose_1/transpose"
#       op: "Transpose"
#       input: "model_1/tf.compat.v1.transpose/transpose:y:0"
#       input: "model_1/tf.compat.v1.transpose_1/transpose/perm:output:0"
#       attr {
#         key: "T"
#         value {
#           type: DT_FLOAT
#         }
#       }
#       attr {
#         key: "Tperm"
#         value {
#           type: DT_INT32
#         }
#       }
#     }
#     node_def {
#       name: "model_1/tf.nn.convolution/convolution"
#       op: "Conv2D"
#       input: "model_1/tf.compat.v1.transpose_1/transpose:y:0"
#       input: "model_1_tf_nn_convolution_convolution_filter"
#       attr {
#         key: "T"
#         value {
#           type: DT_FLOAT
#         }
#       }
#       attr {
#         key: "data_format"
#         value {
#           s: "NHWC"
#         }
#       }
#       attr {
#         key: "dilations"
#         value {
#           list {
#             i: 1
#             i: 1
#             i: 1
#             i: 1
#           }
#         }
#       }
#       attr {
#         key: "explicit_paddings"
#         value {
#           list {
#           }
#         }
#       }
#       attr {
#         key: "padding"
#         value {
#           s: "VALID"
#         }
#       }
#       attr {
#         key: "strides"
#         value {
#           list {
#             i: 1
#             i: 1
#             i: 1
#             i: 1
#           }
#         }
#       }
#       attr {
#         key: "use_cudnn_on_gpu"
#         value {
#           b: true
#         }
#       }
#     }
#     node_def {
#       name: "model_1/tf.nn.relu/Relu"
#       op: "Relu"
#       input: "model_1/tf.nn.convolution/convolution:output:0"
#       attr {
#         key: "T"
#         value {
#           type: DT_FLOAT
#         }
#       }
#     }
#     node_def {
#       name: "model_1/tf.nn.max_pool2d/MaxPool2d"
#       op: "MaxPool"
#       input: "model_1/tf.nn.relu/Relu:activations:0"
#       attr {
#         key: "T"
#         value {
#           type: DT_FLOAT
#         }
#       }
#       attr {
#         key: "data_format"
#         value {
#           s: "NHWC"
#         }
#       }
#       attr {
#         key: "explicit_paddings"
#         value {
#           list {
#           }
#         }
#       }
#       attr {
#         key: "ksize"
#         value {
#           list {
#             i: 1
#             i: 2
#             i: 2
#             i: 1
#           }
#         }
#       }
#       attr {
#         key: "padding"
#         value {
#           s: "VALID"
#         }
#       }
#       attr {
#         key: "strides"
#         value {
#           list {
#             i: 1
#             i: 2
#             i: 2
#             i: 1
#           }
#         }
#       }
#     }
#     node_def {
#       name: "model_1/tf.nn.convolution_1/convolution"
#       op: "Conv2D"
#       input: "model_1/tf.nn.max_pool2d/MaxPool2d:output:0"
#       input: "model_1_tf_nn_convolution_1_convolution_filter"
#       attr {
#         key: "T"
#         value {
#           type: DT_FLOAT
#         }
#       }
#       attr {
#         key: "data_format"
#         value {
#           s: "NHWC"
#         }
#       }
#       attr {
#         key: "dilations"
#         value {
#           list {
#             i: 1
#             i: 1
#             i: 1
#             i: 1
#           }
#         }
#       }
#       attr {
#         key: "explicit_paddings"
#         value {
#           list {
#           }
#         }
#       }
#       attr {
#         key: "padding"
#         value {
#           s: "VALID"
#         }
#       }
#       attr {
#         key: "strides"
#         value {
#           list {
#             i: 1
#             i: 1
#             i: 1
#             i: 1
#           }
#         }
#       }
#       attr {
#         key: "use_cudnn_on_gpu"
#         value {
#           b: true
#         }
#       }
#     }
#     node_def {
#       name: "model_1/tf.nn.relu_1/Relu"
#       op: "Relu"
#       input: "model_1/tf.nn.convolution_1/convolution:output:0"
#       attr {
#         key: "T"
#         value {
#           type: DT_FLOAT
#         }
#       }
#     }
#     node_def {
#       name: "model_1/tf.nn.max_pool2d_1/MaxPool2d"
#       op: "MaxPool"
#       input: "model_1/tf.nn.relu_1/Relu:activations:0"
#       attr {
#         key: "T"
#         value {
#           type: DT_FLOAT
#         }
#       }
#       attr {
#         key: "data_format"
#         value {
#           s: "NHWC"
#         }
#       }
#       attr {
#         key: "explicit_paddings"
#         value {
#           list {
#           }
#         }
#       }
#       attr {
#         key: "ksize"
#         value {
#           list {
#             i: 1
#             i: 2
#             i: 2
#             i: 1
#           }
#         }
#       }
#       attr {
#         key: "padding"
#         value {
#           s: "VALID"
#         }
#       }
#       attr {
#         key: "strides"
#         value {
#           list {
#             i: 1
#             i: 2
#             i: 2
#             i: 1
#           }
#         }
#       }
#     }
#     node_def {
#       name: "model_1/tf.nn.convolution_2/convolution"
#       op: "Conv2D"
#       input: "model_1/tf.nn.max_pool2d_1/MaxPool2d:output:0"
#       input: "model_1_tf_nn_convolution_2_convolution_filter"
#       attr {
#         key: "T"
#         value {
#           type: DT_FLOAT
#         }
#       }
#       attr {
#         key: "data_format"
#         value {
#           s: "NHWC"
#         }
#       }
#       attr {
#         key: "dilations"
#         value {
#           list {
#             i: 1
#             i: 1
#             i: 1
#             i: 1
#           }
#         }
#       }
#       attr {
#         key: "explicit_paddings"
#         value {
#           list {
#           }
#         }
#       }
#       attr {
#         key: "padding"
#         value {
#           s: "VALID"
#         }
#       }
#       attr {
#         key: "strides"
#         value {
#           list {
#             i: 1
#             i: 1
#             i: 1
#             i: 1
#           }
#         }
#       }
#       attr {
#         key: "use_cudnn_on_gpu"
#         value {
#           b: true
#         }
#       }
#     }
#     node_def {
#       name: "model_1/tf.nn.relu_2/Relu"
#       op: "Relu"
#       input: "model_1/tf.nn.convolution_2/convolution:output:0"
#       attr {
#         key: "T"
#         value {
#           type: DT_FLOAT
#         }
#       }
#     }
#     node_def {
#       name: "model_1/tf.nn.max_pool2d_2/MaxPool2d"
#       op: "MaxPool"
#       input: "model_1/tf.nn.relu_2/Relu:activations:0"
#       attr {
#         key: "T"
#         value {
#           type: DT_FLOAT
#         }
#       }
#       attr {
#         key: "data_format"
#         value {
#           s: "NHWC"
#         }
#       }
#       attr {
#         key: "explicit_paddings"
#         value {
#           list {
#           }
#         }
#       }
#       attr {
#         key: "ksize"
#         value {
#           list {
#             i: 1
#             i: 2
#             i: 2
#             i: 1
#           }
#         }
#       }
#       attr {
#         key: "padding"
#         value {
#           s: "VALID"
#         }
#       }
#       attr {
#         key: "strides"
#         value {
#           list {
#             i: 1
#             i: 2
#             i: 2
#             i: 1
#           }
#         }
#       }
#     }
#     node_def {
#       name: "model_1/tf.reshape/Reshape/shape"
#       op: "Const"
#       attr {
#         key: "dtype"
#         value {
#           type: DT_INT32
#         }
#       }
#       attr {
#         key: "value"
#         value {
#           tensor {
#             dtype: DT_INT32
#             tensor_shape {
#               dim {
#                 size: 2
#               }
#             }
#             tensor_content: "\001\000\000\000L\002\000\000"
#           }
#         }
#       }
#     }
#     node_def {
#       name: "model_1/tf.reshape/Reshape"
#       op: "Reshape"
#       input: "model_1/tf.nn.max_pool2d_2/MaxPool2d:output:0"
#       input: "model_1/tf.reshape/Reshape/shape:output:0"
#       attr {
#         key: "T"
#         value {
#           type: DT_FLOAT
#         }
#       }
#       attr {
#         key: "Tshape"
#         value {
#           type: DT_INT32
#         }
#       }
#     }
#     node_def {
#       name: "model_1/tf.linalg.matmul/MatMul"
#       op: "MatMul"
#       input: "model_1/tf.reshape/Reshape:output:0"
#       input: "model_1_tf_linalg_matmul_matmul_b"
#       attr {
#         key: "T"
#         value {
#           type: DT_FLOAT
#         }
#       }
#       attr {
#         key: "grad_a"
#         value {
#           b: false
#         }
#       }
#       attr {
#         key: "grad_b"
#         value {
#           b: false
#         }
#       }
#       attr {
#         key: "transpose_a"
#         value {
#           b: false
#         }
#       }
#       attr {
#         key: "transpose_b"
#         value {
#           b: false
#         }
#       }
#     }
#     node_def {
#       name: "model_1/tf.math.add/Add"
#       op: "AddV2"
#       input: "model_1/tf.linalg.matmul/MatMul:product:0"
#       input: "model_1_tf_math_add_add_y"
#       attr {
#         key: "T"
#         value {
#           type: DT_FLOAT
#         }
#       }
#     }
#     node_def {
#       name: "model_1/tf.nn.relu_3/Relu"
#       op: "Relu"
#       input: "model_1/tf.math.add/Add:z:0"
#       attr {
#         key: "T"
#         value {
#           type: DT_FLOAT
#         }
#       }
#     }
#     node_def {
#       name: "model_1/tf.linalg.matmul_1/MatMul"
#       op: "MatMul"
#       input: "model_1/tf.nn.relu_3/Relu:activations:0"
#       input: "model_1_tf_linalg_matmul_1_matmul_b"
#       attr {
#         key: "T"
#         value {
#           type: DT_FLOAT
#         }
#       }
#       attr {
#         key: "grad_a"
#         value {
#           b: false
#         }
#       }
#       attr {
#         key: "grad_b"
#         value {
#           b: false
#         }
#       }
#       attr {
#         key: "transpose_a"
#         value {
#           b: false
#         }
#       }
#       attr {
#         key: "transpose_b"
#         value {
#           b: false
#         }
#       }
#     }
#     node_def {
#       name: "model_1/tf.math.add_1/Add"
#       op: "AddV2"
#       input: "model_1/tf.linalg.matmul_1/MatMul:product:0"
#       input: "model_1_tf_math_add_1_add_y"
#       attr {
#         key: "T"
#         value {
#           type: DT_FLOAT
#         }
#       }
#     }
#     node_def {
#       name: "model_1/node_17/node_17"
#       op: "Softmax"
#       input: "model_1/tf.math.add_1/Add:z:0"
#       attr {
#         key: "T"
#         value {
#           type: DT_FLOAT
#         }
#       }
#     }
#     node_def {
#       name: "Identity"
#       op: "Identity"
#       input: "model_1/node_17/node_17:softmax:0"
#       attr {
#         key: "T"
#         value {
#           type: DT_FLOAT
#         }
#       }
#     }
#     ret {
#       key: "identity"
#       value: "Identity:output:0"
#     }
#     attr {
#       key: "_construction_context"
#       value {
#         s: "kEagerRuntime"
#       }
#     }
#     arg_attr {
#       value {
#         attr {
#           key: "_output_shapes"
#           value {
#             list {
#               shape {
#                 dim {
#                   size: 1
#                 }
#                 dim {
#                   size: 128
#                 }
#                 dim {
#                   size: 128
#                 }
#                 dim {
#                   size: 3
#                 }
#               }
#             }
#           }
#         }
#         attr {
#           key: "_user_specified_name"
#           value {
#             s: "data"
#           }
#         }
#       }
#     }
#     arg_attr {
#       key: 1
#       value {
#         attr {
#           key: "_output_shapes"
#           value {
#             list {
#               shape {
#                 dim {
#                   size: 3
#                 }
#                 dim {
#                   size: 3
#                 }
#                 dim {
#                   size: 3
#                 }
#                 dim {
#                   size: 3
#                 }
#               }
#             }
#           }
#         }
#       }
#     }
#     arg_attr {
#       key: 2
#       value {
#         attr {
#           key: "_output_shapes"
#           value {
#             list {
#               shape {
#                 dim {
#                   size: 3
#                 }
#                 dim {
#                   size: 3
#                 }
#                 dim {
#                   size: 3
#                 }
#                 dim {
#                   size: 3
#                 }
#               }
#             }
#           }
#         }
#       }
#     }
#     arg_attr {
#       key: 3
#       value {
#         attr {
#           key: "_output_shapes"
#           value {
#             list {
#               shape {
#                 dim {
#                   size: 3
#                 }
#                 dim {
#                   size: 3
#                 }
#                 dim {
#                   size: 3
#                 }
#                 dim {
#                   size: 3
#                 }
#               }
#             }
#           }
#         }
#       }
#     }
#     arg_attr {
#       key: 4
#       value {
#         attr {
#           key: "_output_shapes"
#           value {
#             list {
#               shape {
#                 dim {
#                   size: 588
#                 }
#                 dim {
#                   size: 2
#                 }
#               }
#             }
#           }
#         }
#         attr {
#           key: "_user_specified_name"
#           value {
#             s: "b"
#           }
#         }
#       }
#     }
#     arg_attr {
#       key: 5
#       value {
#         attr {
#           key: "_output_shapes"
#           value {
#             list {
#               shape {
#                 dim {
#                   size: 1
#                 }
#                 dim {
#                   size: 2
#                 }
#               }
#             }
#           }
#         }
#       }
#     }
#     arg_attr {
#       key: 6
#       value {
#         attr {
#           key: "_output_shapes"
#           value {
#             list {
#               shape {
#                 dim {
#                   size: 2
#                 }
#                 dim {
#                   size: 2
#                 }
#               }
#             }
#           }
#         }
#       }
#     }
#     arg_attr {
#       key: 7
#       value {
#         attr {
#           key: "_output_shapes"
#           value {
#             list {
#               shape {
#                 dim {
#                   size: 1
#                 }
#                 dim {
#                   size: 2
#                 }
#               }
#             }
#           }
#         }
#       }
#     }
#   }
# }
# versions {
#   producer: 1882
#   min_consumer: 12
# }

# %%
function_library = tf_graph.library
function_defs = [f for f in function_library.function]

# %%
node_def_attrs = [{'op': n.op, 'input': n.input, "output": n.name} for n in function_defs[0].node_def]
node_def_attrs
# Out:
# [{'op': 'Const',
#   'input': [],
#   'output': 'model_1/tf.compat.v1.transpose/transpose/perm'},
#  {'op': 'Transpose',
#   'input': ['data', 'model_1/tf.compat.v1.transpose/transpose/perm:output:0'],
#   'output': 'model_1/tf.compat.v1.transpose/transpose'},
#  {'op': 'Const',
#   'input': [],
#   'output': 'model_1/tf.compat.v1.transpose_1/transpose/perm'},
#  {'op': 'Transpose',
#   'input': ['model_1/tf.compat.v1.transpose/transpose:y:0', 'model_1/tf.compat.v1.transpose_1/transpose/perm:output:0'],
#   'output': 'model_1/tf.compat.v1.transpose_1/transpose'},
#  {'op': 'Conv2D',
#   'input': ['model_1/tf.compat.v1.transpose_1/transpose:y:0', 'model_1_tf_nn_convolution_convolution_filter'],
#   'output': 'model_1/tf.nn.convolution/convolution'},
#  {'op': 'Relu',
#   'input': ['model_1/tf.nn.convolution/convolution:output:0'],
#   'output': 'model_1/tf.nn.relu/Relu'},
#  {'op': 'MaxPool',
#   'input': ['model_1/tf.nn.relu/Relu:activations:0'],
#   'output': 'model_1/tf.nn.max_pool2d/MaxPool2d'},
#  {'op': 'Conv2D',
#   'input': ['model_1/tf.nn.max_pool2d/MaxPool2d:output:0', 'model_1_tf_nn_convolution_1_convolution_filter'],
#   'output': 'model_1/tf.nn.convolution_1/convolution'},
#  {'op': 'Relu',
#   'input': ['model_1/tf.nn.convolution_1/convolution:output:0'],
#   'output': 'model_1/tf.nn.relu_1/Relu'},
#  {'op': 'MaxPool',
#   'input': ['model_1/tf.nn.relu_1/Relu:activations:0'],
#   'output': 'model_1/tf.nn.max_pool2d_1/MaxPool2d'},
#  {'op': 'Conv2D',
#   'input': ['model_1/tf.nn.max_pool2d_1/MaxPool2d:output:0', 'model_1_tf_nn_convolution_2_convolution_filter'],
#   'output': 'model_1/tf.nn.convolution_2/convolution'},
#  {'op': 'Relu',
#   'input': ['model_1/tf.nn.convolution_2/convolution:output:0'],
#   'output': 'model_1/tf.nn.relu_2/Relu'},
#  {'op': 'MaxPool',
#   'input': ['model_1/tf.nn.relu_2/Relu:activations:0'],
#   'output': 'model_1/tf.nn.max_pool2d_2/MaxPool2d'},
#  {'op': 'Const', 'input': [], 'output': 'model_1/tf.reshape/Reshape/shape'},
#  {'op': 'Reshape',
#   'input': ['model_1/tf.nn.max_pool2d_2/MaxPool2d:output:0', 'model_1/tf.reshape/Reshape/shape:output:0'],
#   'output': 'model_1/tf.reshape/Reshape'},
#  {'op': 'MatMul',
#   'input': ['model_1/tf.reshape/Reshape:output:0', 'model_1_tf_linalg_matmul_matmul_b'],
#   'output': 'model_1/tf.linalg.matmul/MatMul'},
#  {'op': 'AddV2',
#   'input': ['model_1/tf.linalg.matmul/MatMul:product:0', 'model_1_tf_math_add_add_y'],
#   'output': 'model_1/tf.math.add/Add'},
#  {'op': 'Relu',
#   'input': ['model_1/tf.math.add/Add:z:0'],
#   'output': 'model_1/tf.nn.relu_3/Relu'},
#  {'op': 'MatMul',
#   'input': ['model_1/tf.nn.relu_3/Relu:activations:0', 'model_1_tf_linalg_matmul_1_matmul_b'],
#   'output': 'model_1/tf.linalg.matmul_1/MatMul'},
#  {'op': 'AddV2',
#   'input': ['model_1/tf.linalg.matmul_1/MatMul:product:0', 'model_1_tf_math_add_1_add_y'],
#   'output': 'model_1/tf.math.add_1/Add'},
#  {'op': 'Softmax',
#   'input': ['model_1/tf.math.add_1/Add:z:0'],
#   'output': 'model_1/node_17/node_17'},
#  {'op': 'Identity',
#   'input': ['model_1/node_17/node_17:softmax:0'],
#   'output': 'Identity'}]

# %%
with open(os.path.join("..", "config", "tflm.json"), "r") as f:
    tflm_data = json.loads(f.read())

valid_node_defs = [n for n in node_def_attrs if n['op'] in tflm_data['operators'] and n['input'] != []]

# %%
node_shapes = [n.attr.get('shape', None) for n in tf_graph.node]
node_shapes
# Out:
# [shape {
#    dim {
#      size: 1
#    }
#    dim {
#      size: 128
#    }
#    dim {
#      size: 128
#    }
#    dim {
#      size: 3
#    }
#  },
#  shape {
#    dim {
#      size: 3
#    }
#    dim {
#      size: 3
#    }
#    dim {
#      size: 3
#    }
#    dim {
#      size: 3
#    }
#  },
#  shape {
#    dim {
#      size: 3
#    }
#    dim {
#      size: 3
#    }
#    dim {
#      size: 3
#    }
#    dim {
#      size: 3
#    }
#  },
#  shape {
#    dim {
#      size: 3
#    }
#    dim {
#      size: 3
#    }
#    dim {
#      size: 3
#    }
#    dim {
#      size: 3
#    }
#  },
#  shape {
#    dim {
#      size: 588
#    }
#    dim {
#      size: 2
#    }
#  },
#  shape {
#    dim {
#      size: 1
#    }
#    dim {
#      size: 2
#    }
#  },
#  shape {
#    dim {
#      size: 2
#    }
#    dim {
#      size: 2
#    }
#  },
#  shape {
#    dim {
#      size: 1
#    }
#    dim {
#      size: 2
#    }
#  },
#  None,
#  None]

# %%
valid_node_defs
# Out:
# [{'op': 'Transpose',
#   'input': ['data', 'model_1/tf.compat.v1.transpose/transpose/perm:output:0'],
#   'output': 'model_1/tf.compat.v1.transpose/transpose'},
#  {'op': 'Transpose',
#   'input': ['model_1/tf.compat.v1.transpose/transpose:y:0', 'model_1/tf.compat.v1.transpose_1/transpose/perm:output:0'],
#   'output': 'model_1/tf.compat.v1.transpose_1/transpose'},
#  {'op': 'Conv2D',
#   'input': ['model_1/tf.compat.v1.transpose_1/transpose:y:0', 'model_1_tf_nn_convolution_convolution_filter'],
#   'output': 'model_1/tf.nn.convolution/convolution'},
#  {'op': 'Relu',
#   'input': ['model_1/tf.nn.convolution/convolution:output:0'],
#   'output': 'model_1/tf.nn.relu/Relu'},
#  {'op': 'Conv2D',
#   'input': ['model_1/tf.nn.max_pool2d/MaxPool2d:output:0', 'model_1_tf_nn_convolution_1_convolution_filter'],
#   'output': 'model_1/tf.nn.convolution_1/convolution'},
#  {'op': 'Relu',
#   'input': ['model_1/tf.nn.convolution_1/convolution:output:0'],
#   'output': 'model_1/tf.nn.relu_1/Relu'},
#  {'op': 'Conv2D',
#   'input': ['model_1/tf.nn.max_pool2d_1/MaxPool2d:output:0', 'model_1_tf_nn_convolution_2_convolution_filter'],
#   'output': 'model_1/tf.nn.convolution_2/convolution'},
#  {'op': 'Relu',
#   'input': ['model_1/tf.nn.convolution_2/convolution:output:0'],
#   'output': 'model_1/tf.nn.relu_2/Relu'},
#  {'op': 'Reshape',
#   'input': ['model_1/tf.nn.max_pool2d_2/MaxPool2d:output:0', 'model_1/tf.reshape/Reshape/shape:output:0'],
#   'output': 'model_1/tf.reshape/Reshape'},
#  {'op': 'Relu',
#   'input': ['model_1/tf.math.add/Add:z:0'],
#   'output': 'model_1/tf.nn.relu_3/Relu'},
#  {'op': 'Softmax',
#   'input': ['model_1/tf.math.add_1/Add:z:0'],
#   'output': 'model_1/node_17/node_17'}]

# %% [markdown]
# Now, let's try and see if we can get the op, attribute, and shape information into
# networkx graph nodes and use the input/output information to create edges in the networkx graph.
