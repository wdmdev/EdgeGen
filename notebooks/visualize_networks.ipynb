# %% [markdown]
# # Visualizing Generated Networks

# %%
from edgegen.plot.plot_supergraph import get_supergraph_figure

# %% [markdown]
# ## Super Graph
# The super graph is a networkx graph containing all supported operators and their connects extracted from the neural networks in the Younger Dataset.

# %%
supergraph_fig = get_supergraph_figure()

supergraph_fig.show()
# Out:
# Loading super_graph data from /home/wdm/EdgeGen/src/edgegen/design_space/architectures/younger/super_graph.pkl
# /tmp/ipykernel_350422/789140332.py:3: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   supergraph_fig.show()
